# %% [markdown]
# # Creat a list for color names

# %%
from ColorNames import*
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-8-0e598bf035c9> in <module>
# ----> 1 from ColorNames import*
#
# ModuleNotFoundError: No module named 'ColorNames'

# %%
def returnColorList():
    cnames = {
'aliceblue':            '#F0F8FF',
'antiquewhite':         '#FAEBD7',
'aqua':                 '#00FFFF',
'aquamarine':           '#7FFFD4',
'azure':                '#F0FFFF',
'beige':                '#F5F5DC',
'bisque':               '#FFE4C4',
'black':                '#000000',
'blanchedalmond':       '#FFEBCD',
'blue':                 '#0000FF',
'blueviolet':           '#8A2BE2',
'brown':                '#A52A2A',
'burlywood':            '#DEB887',
'cadetblue':            '#5F9EA0',
'chartreuse':           '#7FFF00',
'chocolate':            '#D2691E',
'coral':                '#FF7F50',
'cornflowerblue':       '#6495ED',
'cornsilk':             '#FFF8DC',
'crimson':              '#DC143C',
'cyan':                 '#00FFFF',
'darkblue':             '#00008B',
'darkcyan':             '#008B8B',
'darkgoldenrod':        '#B8860B',
'darkgray':             '#A9A9A9',
'darkgreen':            '#006400',
'darkkhaki':            '#BDB76B',
'darkmagenta':          '#8B008B',
'darkolivegreen':       '#556B2F',
'darkorange':           '#FF8C00',
'darkorchid':           '#9932CC',
'darkred':              '#8B0000',
'darksalmon':           '#E9967A',
'darkseagreen':         '#8FBC8F',
'darkslateblue':        '#483D8B',
'darkslategray':        '#2F4F4F',
'darkturquoise':        '#00CED1',
'darkviolet':           '#9400D3',
'deeppink':             '#FF1493',
'deepskyblue':          '#00BFFF',
'dimgray':              '#696969',
'dodgerblue':           '#1E90FF',
'firebrick':            '#B22222',
'floralwhite':          '#FFFAF0',
'forestgreen':          '#228B22',
'fuchsia':              '#FF00FF',
'gainsboro':            '#DCDCDC',
'ghostwhite':           '#F8F8FF',
'gold':                 '#FFD700',
'goldenrod':            '#DAA520',
'gray':                 '#808080',
'green':                '#008000',
'greenyellow':          '#ADFF2F',
'honeydew':             '#F0FFF0',
'hotpink':              '#FF69B4',
'indianred':            '#CD5C5C',
'indigo':               '#4B0082',
'ivory':                '#FFFFF0',
'khaki':                '#F0E68C',
'lavender':             '#E6E6FA',
'lavenderblush':        '#FFF0F5',
'lawngreen':            '#7CFC00',
'lemonchiffon':         '#FFFACD',
'lightblue':            '#ADD8E6',
'lightcoral':           '#F08080',
'lightcyan':            '#E0FFFF',
'lightgoldenrodyellow': '#FAFAD2',
'lightgreen':           '#90EE90',
'lightgray':            '#D3D3D3',
'lightpink':            '#FFB6C1',
'lightsalmon':          '#FFA07A',
'lightseagreen':        '#20B2AA',
'lightskyblue':         '#87CEFA',
'lightslategray':       '#778899',
'lightsteelblue':       '#B0C4DE',
'lightyellow':          '#FFFFE0',
'lime':                 '#00FF00',
'limegreen':            '#32CD32',
'linen':                '#FAF0E6',
'magenta':              '#FF00FF',
'maroon':               '#800000',
'mediumaquamarine':     '#66CDAA',
'mediumblue':           '#0000CD',
'mediumorchid':         '#BA55D3',
'mediumpurple':         '#9370DB',
'mediumseagreen':       '#3CB371',
'mediumslateblue':      '#7B68EE',
'mediumspringgreen':    '#00FA9A',
'mediumturquoise':      '#48D1CC',
'mediumvioletred':      '#C71585',
'midnightblue':         '#191970',
'mintcream':            '#F5FFFA',
'mistyrose':            '#FFE4E1',
'moccasin':             '#FFE4B5',
'navajowhite':          '#FFDEAD',
'navy':                 '#000080',
'oldlace':              '#FDF5E6',
'olive':                '#808000',
'olivedrab':            '#6B8E23',
'orange':               '#FFA500',
'orangered':            '#FF4500',
'orchid':               '#DA70D6',
'palegoldenrod':        '#EEE8AA',
'palegreen':            '#98FB98',
'paleturquoise':        '#AFEEEE',
'palevioletred':        '#DB7093',
'papayawhip':           '#FFEFD5',
'peachpuff':            '#FFDAB9',
'peru':                 '#CD853F',
'pink':                 '#FFC0CB',
'plum':                 '#DDA0DD',
'powderblue':           '#B0E0E6',
'purple':               '#800080',
'red':                  '#FF0000',
'rosybrown':            '#BC8F8F',
'royalblue':            '#4169E1',
'saddlebrown':          '#8B4513',
'salmon':               '#FA8072',
'sandybrown':           '#FAA460',
'seagreen':             '#2E8B57',
'seashell':             '#FFF5EE',
'sienna':               '#A0522D',
'silver':               '#C0C0C0',
'skyblue':              '#87CEEB',
'slateblue':            '#6A5ACD',
'slategray':            '#708090',
'snow':                 '#FFFAFA',
'springgreen':          '#00FF7F',
'steelblue':            '#4682B4',
'tan':                  '#D2B48C',
'teal':                 '#008080',
'thistle':              '#D8BFD8',
'tomato':               '#FF6347',
'turquoise':            '#40E0D0',
'violet':               '#EE82EE',
'wheat':                '#F5DEB3',
'white':                '#FFFFFF',
'whitesmoke':           '#F5F5F5',
'yellow':               '#FFFF00',
'yellowgreen':          '#9ACD32'}
    colornames = list(cnames.keys())
    return colornames

# %% [markdown]
# # Greedy algorithm, change adjacency list to matrix before coloring

# %%
def matrix_to_list(matrix):
    start = 0
    res = []
    N = len(matrix)

    for i in range(N):
        res.append([]*N)
    while start < N:
        y = matrix[start]
        for i in range(len(y)):
            if y[i] == 1:
                res[start].append(i)
        start += 1
    return res

def greedy(graph):
    
    colors = returnColorList()
    names = []
    for i in range (1, 150):
        names.append(i)
    
    Nodes = len(graph)
    result = [-1] * Nodes    # Initialize all vertices are unassigned
    result[0] = 0            # Assign first color for the first node

    color_available = [False] * Nodes
    counter = []

    for u in range (1,Nodes):     # for all other Nodes-1 vertices
        for i in graph[u]:
                if result[i] != -1: # when one color is assigned, make is unavailable
                    color_available[result[i]] = True
        
        color = 0
        while color < Nodes:
            if color_available[color] == False:
                break            # find a color which is not assigned
            color += 1
        result[u] = color        # assign found color in the list
        
        for i in graph[u]:       # for next iteration make color availability to false
                if result[i] != -1:
                    color_available[result[i]] = False

    for u in range(Nodes):
        counter.append(colors[result[u]])
        print("Vertex", names[u], "Assigned with Color", colors[result[u]])
    
    color_counter = set(counter)
    print("The greedy algorithm used", len(color_counter), "colors that include", str(color_counter))

# %% [markdown]
# # dataset myciel3.txt.txt

# %%
#11 nodes 20 edges 4 colors
dataset1 = []
file = open("myciel3.txt.txt")
lines = file.read().splitlines()
for i in lines:
    dataset1.append(i.split(" ")[1:])
#print(dataset1)
adjm11=[]
for i in range(11):
    l = [0]*11
    adjm11.append(l)

for i in dataset1:
    adjm11[int(i[0])-1][int(i[1])-1] = 1
    adjm11[int(i[1])-1][int(i[0])-1] = 1
#print(adjm11)
greedy(matrix_to_list(adjm11))
# Out:
# Vertex 1 Assigned with Color aliceblue
# Vertex 2 Assigned with Color antiquewhite
# Vertex 3 Assigned with Color aliceblue
# Vertex 4 Assigned with Color antiquewhite
# Vertex 5 Assigned with Color aqua
# Vertex 6 Assigned with Color aliceblue
# Vertex 7 Assigned with Color antiquewhite
# Vertex 8 Assigned with Color aliceblue
# Vertex 9 Assigned with Color antiquewhite
# Vertex 10 Assigned with Color aqua
# Vertex 11 Assigned with Color aquamarine
# The greedy algorithm used 4 colors that include {'antiquewhite', 'aqua', 'aquamarine', 'aliceblue'}

# %% [markdown]
# # dataset queen8_8.txt.txt

# %%
#64 nodes 728 edges 9 colors
dataset1 = []
file = open("queen8_8.txt.txt")
lines = file.read().splitlines()
for i in lines:
    dataset1.append(i.split(" ")[1:])
#print(dataset1)

adjm64=[]
for i in range(64):
    l = [0]*64
    adjm64.append(l)

for i in dataset1:
    adjm64[int(i[0])-1][int(i[1])-1] = 1
    adjm64[int(i[1])-1][int(i[0])-1] = 1
#print(adjm64)
greedy(matrix_to_list(adjm64))
# Out:
# Vertex 1 Assigned with Color aliceblue
# Vertex 2 Assigned with Color antiquewhite
# Vertex 3 Assigned with Color aqua
# Vertex 4 Assigned with Color aquamarine
# Vertex 5 Assigned with Color azure
# Vertex 6 Assigned with Color beige
# Vertex 7 Assigned with Color bisque
# Vertex 8 Assigned with Color black
# Vertex 9 Assigned with Color aqua
# Vertex 10 Assigned with Color aquamarine
# Vertex 11 Assigned with Color aliceblue
# Vertex 12 Assigned with Color antiquewhite
# Vertex 13 Assigned with Color bisque
# Vertex 14 Assigned with Color black
# Vertex 15 Assigned with Color azure
# Vertex 16 Assigned with Color beige
# Vertex 17 Assigned with Color antiquewhite
# Vertex 18 Assigned with Color azure
# Vertex 19 Assigned with Color beige
# Vertex 20 Assigned with Color aqua
# Vertex 21 Assigned with Color aliceblue
# Vertex 22 Assigned with Color blanchedalmond
# Vertex 23 Assigned with Color aquamarine
# Vertex 24 Assigned with Color bisque
# Vertex 25 Assigned with Color beige
# ...

# %% [markdown]
# # dataset miles500.txt.txt

# %%
#128 nodes 1170 edges 20 colors
dataset1 = []
file = open("miles500.txt.txt")
lines = file.read().splitlines()
for i in lines:
    dataset1.append(i.split(" ")[1:])
#print(dataset1)
adjm128_1=[]
for i in range(128):
    l = [0]*128
    adjm128_1.append(l)

for i in dataset1:
    adjm128_1[int(i[0])-1][int(i[1])-1] = 1
    adjm128_1[int(i[1])-1][int(i[0])-1] = 1
#print(adjm128_1)
greedy(matrix_to_list(adjm128_1))
# Out:
# Vertex 1 Assigned with Color aliceblue
# Vertex 2 Assigned with Color aliceblue
# Vertex 3 Assigned with Color aliceblue
# Vertex 4 Assigned with Color aliceblue
# Vertex 5 Assigned with Color antiquewhite
# Vertex 6 Assigned with Color aliceblue
# Vertex 7 Assigned with Color aliceblue
# Vertex 8 Assigned with Color antiquewhite
# Vertex 9 Assigned with Color antiquewhite
# Vertex 10 Assigned with Color antiquewhite
# Vertex 11 Assigned with Color aliceblue
# Vertex 12 Assigned with Color aliceblue
# Vertex 13 Assigned with Color antiquewhite
# Vertex 14 Assigned with Color aqua
# Vertex 15 Assigned with Color antiquewhite
# Vertex 16 Assigned with Color antiquewhite
# Vertex 17 Assigned with Color antiquewhite
# Vertex 18 Assigned with Color aqua
# Vertex 19 Assigned with Color aquamarine
# Vertex 20 Assigned with Color aqua
# Vertex 21 Assigned with Color aquamarine
# Vertex 22 Assigned with Color aliceblue
# Vertex 23 Assigned with Color aqua
# ...

# %% [markdown]
# # dataset miles1000.txt.txt

# %%
#128 nodes 3216 edges 42 colors
dataset1 = []
file = open("miles1000.txt.txt")
lines = file.read().splitlines()
for i in lines:
    dataset1.append(i.split(" ")[1:])
#print(dataset1)
adjm128_2=[]
for i in range(128):
    l = [0]*128
    adjm128_2.append(l)

for i in dataset1:
    adjm128_2[int(i[0])-1][int(i[1])-1] = 1
    adjm128_2[int(i[1])-1][int(i[0])-1] = 1
#print(adjm128_2)
greedy(matrix_to_list(adjm128_2))
# Out:
# Vertex 1 Assigned with Color aliceblue
# Vertex 2 Assigned with Color aliceblue
# Vertex 3 Assigned with Color aliceblue
# Vertex 4 Assigned with Color antiquewhite
# Vertex 5 Assigned with Color aqua
# Vertex 6 Assigned with Color antiquewhite
# Vertex 7 Assigned with Color antiquewhite
# Vertex 8 Assigned with Color aqua
# Vertex 9 Assigned with Color aquamarine
# Vertex 10 Assigned with Color aquamarine
# Vertex 11 Assigned with Color azure
# Vertex 12 Assigned with Color antiquewhite
# Vertex 13 Assigned with Color azure
# Vertex 14 Assigned with Color azure
# Vertex 15 Assigned with Color azure
# Vertex 16 Assigned with Color aquamarine
# Vertex 17 Assigned with Color aqua
# Vertex 18 Assigned with Color beige
# Vertex 19 Assigned with Color beige
# Vertex 20 Assigned with Color bisque
# Vertex 21 Assigned with Color bisque
# Vertex 22 Assigned with Color aqua
# Vertex 23 Assigned with Color aqua
# Vertex 24 Assigned with Color beige
# Vertex 25 Assigned with Color black
# ...

# %% [markdown]
# # dataset miles1500.txt.txt

# %%
#128 nodes 5198 edges 73 colors
dataset1 = []
file = open("miles1500.txt.txt")
lines = file.read().splitlines()
for i in lines:
    dataset1.append(i.split(" ")[1:])
#print(dataset1)
adjm128_3=[]
for i in range(128):
    l = [0]*128
    adjm128_3.append(l)

for i in dataset1:
    adjm128_3[int(i[0])-1][int(i[1])-1] = 1
    adjm128_3[int(i[1])-1][int(i[0])-1] = 1
#print(adjm128_3)
greedy(matrix_to_list(adjm128_3))
# Out:
# Vertex 1 Assigned with Color aliceblue
# Vertex 2 Assigned with Color antiquewhite
# Vertex 3 Assigned with Color antiquewhite
# Vertex 4 Assigned with Color aliceblue
# Vertex 5 Assigned with Color aqua
# Vertex 6 Assigned with Color aqua
# Vertex 7 Assigned with Color aquamarine
# Vertex 8 Assigned with Color azure
# Vertex 9 Assigned with Color aquamarine
# Vertex 10 Assigned with Color beige
# Vertex 11 Assigned with Color azure
# Vertex 12 Assigned with Color beige
# Vertex 13 Assigned with Color bisque
# Vertex 14 Assigned with Color black
# Vertex 15 Assigned with Color bisque
# Vertex 16 Assigned with Color blanchedalmond
# Vertex 17 Assigned with Color beige
# Vertex 18 Assigned with Color black
# Vertex 19 Assigned with Color blue
# Vertex 20 Assigned with Color blanchedalmond
# Vertex 21 Assigned with Color blue
# Vertex 22 Assigned with Color aliceblue
# Vertex 23 Assigned with Color blueviolet
# Vertex 24 Assigned with Color brown
# ...
